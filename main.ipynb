# %% [markdown]
# * Archivo principal del proyecto que lee los archivos

# %%
import pandas as pd

df_a_cat = pd.read_csv("C:/Users/rakhe/Desktop/mineria-steam-games/data/steam_dataset_2025_csv/application_categories.csv")
df_app = pd.read_csv("C:/Users/rakhe/Desktop/mineria-steam-games/data/steam_dataset_2025_csv/applications.csv")
df_cat = pd.read_csv("C:/Users/rakhe/Desktop/mineria-steam-games/data-cleaned/categories_clean.csv")
df_rev = pd.read_csv("C:/Users/rakhe/Desktop/mineria-steam-games/data/steam_dataset_2025_csv/reviews.csv")
# Out:
# C:\Users\rakhe\AppData\Local\Temp\ipykernel_34840\3488106942.py:4: DtypeWarning: Columns (0: required_age) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_app = pd.read_csv("C:/Users/rakhe/Desktop/mineria-steam-games/data/steam_dataset_2025_csv/applications.csv")

# %%
vc = df_rev["appid"].value_counts().to_csv("test.csv")
